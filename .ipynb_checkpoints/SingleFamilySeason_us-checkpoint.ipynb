# %% [markdown]
# Observations
# - According to the data, the seasons can affect the inventories and the prices.
# - The inventories tend to decrease in winter and increase in warmer temperatures.
# - Similarly, the prices tend to increase and decrease according to the seasons.
# - Finally, we can conclude that the seasons affect both prices and inventories, but this
#   depends on the location of the state.

# %%
import pandas as pd
#import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# import the csv files
houses_inventory_df = pd.read_csv("../Project-1-Group-8/Resources/Metro_single_family_inventory.csv")

# %%
houses_inventory_df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2017-10-31  2017-11-30  2017-12-31  2018-01-31  2018-02-28  ...  \
# 0       NaN   1473863.0   1363258.0   1214863.0   1213824.0   1231285.0  ...
# 1        NY     61337.0     55858.0     48983.0     47909.0     50994.0  ...
# 2        CA     23988.0     21095.0     17177.0     18596.0     20553.0  ...
# 3        IL     37986.0     33625.0     28506.0     27985.0     29558.0  ...
# 4        TX     28105.0     25409.0     22094.0     21670.0     22246.0  ...
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  \
# 0   1215637.0   1218110.0   1218038.0   1268669.0   1176125.0   1262927.0
# 1     51156.0     50151.0     52234.0     55285.0     45766.0     49691.0
# 2     18619.0     19327.0     20572.0     20720.0     18760.0     21623.0
# 3     30628.0     30609.0     32670.0     34044.0     30218.0     33071.0
# 4     29338.0     29149.0     30126.0     31208.0     29424.0     32729.0
#
#    2020-06-30  2020-07-31  2020-08-31  2020-09-30
# 0   1241911.0   1204523.0   1143870.0   1081314.0
# 1     55193.0     56555.0     54287.0     53324.0
# 2     22811.0     23312.0     22776.0     22177.0
# 3     34072.0     33225.0     31403.0     29268.0
# 4     32253.0     31448.0     28968.0     26158.0
#
# [5 rows x 41 columns]

# %%
# clean the datafile by removing the columns that will not be used
houses_inv_clean_df = houses_inventory_df.drop(columns = ['RegionID','SizeRank','RegionType','RegionName'])

# remove the first row
houses_inv_clean_df = houses_inv_clean_df.drop(houses_inv_clean_df.index[0])

# %%
houses_inv_clean_df.head()
# Out:
#   StateName  2017-10-31  2017-11-30  2017-12-31  2018-01-31  2018-02-28  \
# 1        NY     61337.0     55858.0     48983.0     47909.0     50994.0
# 2        CA     23988.0     21095.0     17177.0     18596.0     20553.0
# 3        IL     37986.0     33625.0     28506.0     27985.0     29558.0
# 4        TX     28105.0     25409.0     22094.0     21670.0     22246.0
# 5        PA     29998.0     28980.0     24460.0     23866.0     24966.0
#
#    2018-03-31  2018-04-30  2018-05-31  2018-06-30  ...  2019-12-31  \
# 1     56041.0     62267.0     66931.0     68737.0  ...     51156.0
# 2     22878.0     24346.0     26308.0     27341.0  ...     18619.0
# 3     34484.0     36556.0     38640.0     40345.0  ...     30628.0
# 4     25388.0     28688.0     30374.0     32433.0  ...     29338.0
# 5     27417.0     30451.0     31622.0     30560.0  ...     22115.0
#
#    2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# 1     50151.0     52234.0     55285.0     45766.0     49691.0     55193.0
# 2     19327.0     20572.0     20720.0     18760.0     21623.0     22811.0
# 3     30609.0     32670.0     34044.0     30218.0     33071.0     34072.0
# 4     29149.0     30126.0     31208.0     29424.0     32729.0     32253.0
# 5     21719.0     22010.0     22274.0     18147.0     20940.0     22664.0
#
#    2020-07-31  2020-08-31  2020-09-30
# 1     56555.0     54287.0     53324.0
# 2     23312.0     22776.0     22177.0
# 3     33225.0     31403.0     29268.0
# 4     31448.0     28968.0     26158.0
# 5     22188.0     21082.0     20431.0
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Calculate the inventory seasonally for the last 3 years

# %%
# fall data average price

# 2017-2018
houses_inv_fall_2018_df = pd.DataFrame(houses_inv_clean_df, columns = ['2017-10-31','2017-11-30'])
houses_fall_2018_total = round(houses_inv_fall_2018_df.sum().mean(),2)

# # 2018-2019 
houses_fall_clean_2019_df = pd.DataFrame(houses_inv_clean_df, columns = ['2018-09-30','2018-10-31','2018-11-30'])
houses_fall_2019_total = round(houses_fall_clean_2019_df.sum().mean(),2)

# # 2019-2020
houses_fall_clean_2020_df = pd.DataFrame(houses_inv_clean_df, columns = ['2019-09-30','2019-10-31','2019-11-30'])
houses_fall_2020_total = round(houses_fall_clean_2020_df.sum().mean(),2)

# %%
# Winter data average price

# 2017-2018
houses_winter_clean_2018_df = pd.DataFrame(houses_inv_clean_df, columns = ['2017-12-31','2018-01-31','2018-02-28'])
houses_winter_2018_total = round(houses_winter_clean_2018_df.sum().mean(),2)

# 2018-2019
houses_winter_clean_2019_df = pd.DataFrame(houses_inv_clean_df, columns = ['2018-12-31','2019-01-31','2019-02-28'])
houses_winter_2019_total = round(houses_winter_clean_2019_df.sum().mean(),2)

# 2019-2020
houses_winter_clean_2020_df = pd.DataFrame(houses_inv_clean_df, columns = ['2019-12-31','2020-01-31','2020-02-29'])
houses_winter_2020_total = round(houses_winter_clean_2020_df.sum().mean(),2)

# %%
# spring data average price

# 2018 
houses_spring_clean_2018_df = pd.DataFrame(houses_inv_clean_df, columns = ['2018-03-31','2018-04-30','2018-05-31'])
houses_spring_2018_total = round(houses_spring_clean_2018_df.sum().mean(),2)
    
# 2019
houses_spring_clean_2019_df = pd.DataFrame(houses_inv_clean_df, columns = ['2019-03-31','2019-04-30','2019-05-31'])
houses_spring_2019_total = round(houses_spring_clean_2019_df.sum().mean(),2)

# 2020
houses_spring_clean_2020_df = pd.DataFrame(houses_inv_clean_df, columns = ['2020-03-31','2020-04-30','2020-05-31'])
houses_spring_2020_total = round(houses_spring_clean_2020_df.sum().mean(),2)

# %%
# summer data average price

# 2018 
houses_summer_clean_2018_df = pd.DataFrame(houses_inv_clean_df, columns = ['2018-06-30','2018-07-31','2018-08-31'])
houses_summer_2018_total = round(houses_summer_clean_2018_df.sum().mean(),2)

# 2019
houses_summer_clean_2019_df = pd.DataFrame(houses_inv_clean_df, columns = ['2019-06-30','2019-07-31','2019-08-31'])
houses_summer_2019_total = round(houses_summer_clean_2019_df.sum().mean(),2)

# 2020
houses_summer_clean_2020_df = pd.DataFrame(houses_inv_clean_df, columns = ['2020-06-30','2020-07-31','2020-08-31'])
houses_summer_2020_total = round(houses_summer_clean_2020_df.sum().mean(),2)

# %%
# list to store the mean of the fall inventory of each season for the 3 years
list_season_fall = []
list_season_fall.append(houses_fall_2018_total)
list_season_fall.append(houses_fall_2019_total)
list_season_fall.append(houses_fall_2020_total)

# list to store the mean of the winter inventory of each season for the 3 years
list_season_winter = []
list_season_winter.append(houses_winter_2018_total)
list_season_winter.append(houses_winter_2019_total)
list_season_winter.append(houses_winter_2020_total)

# list to store the mean of the spring inventory of each season for the 3 years
list_season_spring = []
list_season_spring.append(houses_spring_2018_total)
list_season_spring.append(houses_spring_2019_total)
list_season_spring.append(houses_spring_2020_total)

# list to store the mean of the summer inventory of each season for the 3 years
list_season_summer = []
list_season_summer.append(houses_summer_2018_total)
list_season_summer.append(houses_summer_2019_total)
list_season_summer.append(houses_summer_2020_total)
list_season_fall
# Out:
# [832262.0, 898091.33, 891997.0]

# %%
# created dataframe with an index to plot in a Bar Chart
seasonally_avg_inv = pd.DataFrame({
                            "Fall"  :list_season_fall,
                            "Winter":list_season_winter,
                            "Spring":list_season_spring,
                            "Summer":list_season_summer
    },index=['2017-2018','2018-2019','2019-2020'])

# %%
seasonally_avg_inv
# Out:
#                 Fall     Winter     Spring     Summer
# 2017-2018  832262.00  710339.33  862504.00  937966.67
# 2018-2019  898091.33  771685.33  900236.33  966017.33
# 2019-2020  891997.00  734734.00  756946.67  739487.00

# %%
# Bar Chart
plt.style.use('seaborn') 

ax = seasonally_avg_inv.plot(kind="bar",color = ['gray','blue','red','green'],alpha=0.6, align="center",figsize=(13,8))

plt.xticks(rotation=30, horizontalalignment="center")


# formatted title and labels
plt.title ('Seasonal Zillow Inventory - Single Family - 3 years')
plt.ylabel("Inventory x 100K")
plt.xlabel("Years")

for p in ax.patches:
    label_position = p.get_height()/1.02
    
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., label_position), 
                   ha = 'center', va = 'center', 
                   xytext = (0,12),
                   textcoords = 'offset points')

# save image
plt.savefig("../Project-1-Group-8/Images/seasonalChart.png")

# %% [markdown]
# The Winter inventory always decreases after fall.
# The Spring and Summer inventory tends to increase.
# The Fall inventory decrease after S+pring.
# This year is different than the last two years.

# %% [markdown]
# ### Sale Prices over the seasons

# %%
#import the csv file/ Zillow Sales prices - raw data
house_sale_price_df= pd.read_csv("../Project-1-Group-8/Resources/sale_price_single_family.csv")

# clean data removing the first row which is not a state
house_sale_price_df = house_sale_price_df.iloc[1:,:]
house_sale_price_df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
# 5    394974         5                    Philadelphia, PA        Msa
#
#   StateName  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  ...  \
# 1        NY         NaN         NaN         NaN         NaN         NaN  ...
# 2        CA    535000.0    527000.0    530000.0    510000.0    510000.0  ...
# 3        IL    250000.0    247500.0    252000.0    255000.0    260000.0  ...
# 4        TX    145455.0    154000.0    152950.0    156000.0    161975.0  ...
# 5        PA    218000.0    224000.0    221000.0    230000.0    239000.0  ...
#
#    2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  \
# 1    430000.0    430000.0    431000.0    430000.0    430000.0    448000.0
# 2    660000.0    671000.0    673000.0    677000.0    695000.0    678000.0
# 3    243000.0    240000.0    234000.0    240000.0    256500.0    267000.0
# 4    271945.0    278000.0    268000.0    275000.0    280000.0    287000.0
# 5    250000.0    250000.0    240000.0    240000.0    250000.0    270000.0
#
#    2020-05-31  2020-06-30  2020-07-31  2020-08-31
# 1    450000.0    457000.0    465000.0    480000.0
# 2    665000.0    699000.0    730000.0    749400.0
# 3    259400.0    260500.0    270000.0    280000.0
# 4    281000.0    294900.0    301100.0    300000.0
# 5    263000.0    270000.0    279000.0    280000.0
#
# [5 rows x 156 columns]

# %%
# get the data from the mid month for each season
houses_price_seasonally = pd.DataFrame(house_sale_price_df,columns = ['StateName',
                                                                      '2017-11-30','2018-02-28','2018-05-31','2018-08-31',
                                                                      '2019-11-30','2019-02-28','2019-05-31','2019-08-31',
                                                                      '2020-02-29','2020-05-31','2020-08-31'])

houses_price_seasonally.head()
# Out:
#   StateName  2017-11-30  2018-02-28  2018-05-31  2018-08-31  2019-11-30  \
# 1        NY    400000.0    397500.0    420000.0    442000.0    430000.0
# 2        CA    625000.0    635000.0    665000.0    660000.0    660000.0
# 3        IL    227000.0    225000.0    251000.0    245000.0    243000.0
# 4        TX    254900.0    257013.0    276000.0    270000.0    271945.0
# 5        PA    230000.0    220000.0    242000.0    255000.0    250000.0
#
#    2019-02-28  2019-05-31  2019-08-31  2020-02-29  2020-05-31  2020-08-31
# 1    419900.0    430000.0    445278.0    430000.0    450000.0    480000.0
# 2    639000.0    660000.0    660000.0    677000.0    665000.0    749400.0
# 3    232500.0    256175.0    252000.0    240000.0    259400.0    280000.0
# 4    260000.0    282500.0    277000.0    275000.0    281000.0    300000.0
# 5    225000.0    253250.0    265000.0    240000.0    263000.0    280000.0

# %%
# calculate the mean price for all the US
houses_price_seasonally_mean = round(houses_price_seasonally.mean(),2)

# %%
# calculate the median price for all the US
houses_price_seasonally_median = houses_price_seasonally.median()

# %%
# created a DataFrame wiht the % increase column
house_percentage_increase = pd.DataFrame({'Date':houses_price_seasonally_mean.index,
                                          'Median Price':houses_price_seasonally_median.values,
                                          'Average Price':houses_price_seasonally_mean.values,
                                          '% increase':''})

# %%
# Calculated the percentage changed from one season to another
for index,row in house_percentage_increase.iterrows():
    
    if index >= 1:
        house_percentage_increase.loc[index,'% increase'] = ((house_percentage_increase.loc[index,'Average Price']-
                                                             house_percentage_increase.loc[index -1,'Average Price'])/
                                                             house_percentage_increase.loc[index-1,'Average Price']*100)

# %%
# formatted the numbers
house_percentage_increase['Median Price'] = house_percentage_increase['Median Price'].map("{:,.0f}".format)
house_percentage_increase['Average Price'] = house_percentage_increase['Average Price'].map("{:,.0f}".format)

# %%
house_percentage_increase
# Out:
#           Date Median Price Average Price  % increase
# 0   2017-11-30      223,750       257,458
# 1   2018-02-28      220,000       257,892    0.168567
# 2   2018-05-31      231,500       273,788     6.16404
# 3   2018-08-31      233,950       274,328    0.197149
# 4   2019-11-30      242,500       280,046     2.08415
# 5   2019-02-28      226,375       266,895    -4.69599
# 6   2019-05-31      248,750       284,392     6.55579
# 7   2019-08-31      243,400       284,372 -0.00684971
# 8   2020-02-29      240,000       280,291    -1.43505
# 9   2020-05-31      252,450       294,220     4.96948
# 10  2020-08-31      267,000       314,230     6.80101

# %% [markdown]
# Greatest % Increase in May - 2018-05-31, 2019-05-31, 2020-05-31 which is in Summer
# Greatest % Decrease in February 2019-02-28, 2020-02-29 which is in winter

# %%
# created a line graph

# style
plt.style.use('seaborn')

# figure size
plt.figure(figsize=(12,3))

# plot the graph
plt.plot(houses_price_seasonally_mean,color = 'red',marker='o')
plt.xticks(rotation=-90)

# title and labels
plt.title("3-Year Housing Sale Price Change by season in the US")
plt.xlabel("Mid-season Month")
plt.ylabel("Average Price")

# save image
plt.savefig("../Project-1-Group-8/Images/seasonalLinegraph.png")

plt.show()

# %% [markdown]
# ### House price for the Northern and Southern States

# %%
# create a DataFrame for the Northern and Southern States
house_price_per_state_NV = houses_price_seasonally.loc[houses_price_seasonally.StateName == 'NV']
house_price_per_state_MN = houses_price_seasonally.loc[houses_price_seasonally.StateName == 'MN']
house_price_per_state_FL = houses_price_seasonally.loc[houses_price_seasonally.StateName == 'FL']
house_price_per_state_WI = houses_price_seasonally.loc[houses_price_seasonally.StateName == 'WI']

# %%
# get the average price for each state
house_price_per_state_MN = house_price_per_state_MN.mean()
house_price_per_state_NV = house_price_per_state_NV.mean()
house_price_per_state_FL = house_price_per_state_FL.mean()
house_price_per_state_WI = house_price_per_state_WI.mean()
house_price_per_state_WI
# Out:
# 2017-11-30    220700.0
# 2018-02-28    208500.0
# 2018-05-31    228500.0
# 2018-08-31    239075.0
# 2019-11-30    242450.0
# 2019-02-28    215000.0
# 2019-05-31    249950.0
# 2019-08-31    246825.0
# 2020-02-29    237000.0
# 2020-05-31    262700.0
# 2020-08-31    273250.0
# dtype: float64

# %%
# created a line graph

index_list = house_price_per_state_MN.index.tolist()

plt.style.use('seaborn')

fig, ax = plt.subplots(figsize=(12, 5))

# plot each line
ax.plot(index_list, house_price_per_state_NV.values, label="NV",marker='o')
ax.plot(index_list, house_price_per_state_MN.values, label="MN")
ax.plot(index_list, house_price_per_state_FL.values, label="FL",marker='o')
ax.plot(index_list, house_price_per_state_WI.values, label="WI")

ax.legend( loc='upper left')
plt.title("Comparisson between prices in Northern and Southern climates seasonally")
plt.xlabel("Mid-season Month")
plt.ylabel("Average Price")
plt.xticks(rotation=-90, horizontalalignment="center")

# save image
plt.savefig("../Project-1-Group-8/Images/StatesLinegraph.png")

plt.show()

# %% [markdown]
# The two Southern states (NV and FL) show a more linear trend.
# The two Northern states (MN and WI) show that the house prices are more affected by the seasons.
