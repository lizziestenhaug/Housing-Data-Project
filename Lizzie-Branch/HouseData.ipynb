# %% [markdown]
# # HouseData
#
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import scipy.stats as sts
import numpy as np
import gmaps
from census import Census

# Census API Key
from api_keys import api_key
c = Census(api_key, year=2018)

# %%
# Read in the csv containing reduced data
five_year_data = pd.read_csv('five_year_data.csv')
five_year_data
# Out:
#         9/30/2016      9/30/2017      9/30/2018      9/30/2019      9/30/2020  \
# 0   308459.500000  316272.750000  319276.000000  332741.750000  332180.500000
# 1   112818.809524  116453.809524  122060.904762  127214.428571  135227.476190
# 2    91220.900000   94984.800000   98921.950000  103107.400000  106684.900000
# 3   191720.181818  203693.090909  217927.636364  230183.272727  248400.000000
# 4   396921.454545  421064.264706  452449.382353  452734.352941  480126.794118
# 5   348916.352941  372094.176471  397796.705882  414621.000000  427329.941176
# 6   284310.400000  294524.200000  299656.800000  300244.800000  317361.600000
# 7   402366.000000  417469.000000  432261.000000  443640.000000  469854.000000
# 8   218475.000000  224679.500000  235088.500000  243079.000000  256360.500000
# 9   193960.965517  205772.206897  217678.931034  225917.931034  238672.206897
# 10  113790.000000  119690.189189  127382.000000  134004.405405  138038.972973
# ...

# %%
# median sale price growth over years
mean2016 = five_year_data['9/30/2016'].mean()
mean2017 = five_year_data['9/30/2017'].mean()
mean2018 = five_year_data['9/30/2018'].mean()
mean2019 = five_year_data['9/30/2019'].mean()
mean2020 = five_year_data['9/30/2020'].mean()
#mean2016
#mean2017
mean2018
#mean2019
#mean2020
# Out:
# 214649.47552096896
